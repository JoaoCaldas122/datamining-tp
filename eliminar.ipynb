# %%
import pandas as pd


df = pd.read_csv('fbref/dataset_202223.csv')

df

# df.to_csv('merged_treinofinal.csv', index=False)
# Out:
#      Unnamed: 0  Jornada  Dia        Data Horário          home  xG_home  \
# 0             0        1  sex  2022-08-05   20:15       Benfica      2.7
# 1             1        1  sáb  2022-08-06   15:30       Rio Ave      0.2
# 2             2        1  sáb  2022-08-06   18:00       Estoril      1.8
# 3             3        1  sáb  2022-08-06   20:30         Porto      3.2
# 4             4        1  dom  2022-08-07   14:30   Santa Clara      0.3
# ..          ...      ...  ...         ...     ...           ...      ...
# 301         301       34  dom  2023-05-28   15:30       Benfica      NaN
# 302         302       34  dom  2023-05-28   15:30        Vizela      NaN
# 303         303       34  dom  2023-05-28   15:30  Portimonense      NaN
# 304         304       34  dom  2023-05-28   15:30         Porto      NaN
# 305         305       34  dom  2023-05-28   15:30       Rio Ave      NaN
#
#      xG_away         away  Assistance  ...          jogador10_away  \
# ...

# %%
df = df.iloc[:, 1:]

df
# Out:
#      Jornada  Dia        Data Horário          home  xG_home  xG_away  \
# 0          1  sex  2022-08-05   20:15       Benfica      2.7      0.4
# 1          1  sáb  2022-08-06   15:30       Rio Ave      0.2      1.4
# 2          1  sáb  2022-08-06   18:00       Estoril      1.8      1.5
# 3          1  sáb  2022-08-06   20:30         Porto      3.2      1.6
# 4          1  dom  2022-08-07   14:30   Santa Clara      0.3      1.3
# ..       ...  ...         ...     ...           ...      ...      ...
# 301       34  dom  2023-05-28   15:30       Benfica      NaN      NaN
# 302       34  dom  2023-05-28   15:30        Vizela      NaN      NaN
# 303       34  dom  2023-05-28   15:30  Portimonense      NaN      NaN
# 304       34  dom  2023-05-28   15:30         Porto      NaN      NaN
# 305       34  dom  2023-05-28   15:30       Rio Ave      NaN      NaN
#
#             away  Assistance                              Local  ...  \
# ...

# %%
df = df.iloc[:-2,:]

# %%
df.to_csv('fbref/dataset_202223.csv', index=False)
