# %%
import pandas as pd


df = pd.read_csv('fbref/dataset_202021.csv')

df

# df.to_csv('merged_treinofinal.csv', index=False)
# Out:
#      Unnamed: 0                                        Rodada  Jornada  Dia  \
# 0             0                                Regular season      1.0  sex
# 1             1                                Regular season      1.0  sex
# 2             2                                Regular season      1.0  sáb
# 3             3                                Regular season      1.0  sáb
# 4             4                                Regular season      1.0  dom
# ..          ...                                           ...      ...  ...
# 303         303                                Regular season     34.0  qua
# 304         304                                Regular season     34.0  qua
# 305         305                                Regular season     34.0  qua
# 306         306  Portuguese 1/2 Relegation/Promotion Play-off      NaN  qua
# 307         307  Portuguese 1/2 Relegation/Promotion Play-off      NaN  dom
#
# ...

# %%
df = df.iloc[:, 2:]

df
# Out:
#      Jornada  Dia        Data Horário         home  xG_home  xG_away  \
# 0        1.0  sex  2020-09-18   19:00    Famalicão      0.6      3.0
# 1        1.0  sex  2020-09-18   21:15      Vitória      0.4      0.5
# 2        1.0  sáb  2020-09-19   16:00     Nacional      1.3      0.3
# 3        1.0  sáb  2020-09-19   21:00        Porto      2.7      0.6
# 4        1.0  dom  2020-09-20   15:00  Santa Clara      2.2      1.5
# ..       ...  ...         ...     ...          ...      ...      ...
# 303     34.0  qua  2021-05-19   20:00      Vitória      0.8      1.9
# 304     34.0  qua  2021-05-19   20:00     Nacional      0.7      3.9
# 305     34.0  qua  2021-05-19   21:45  Sporting CP      1.8      0.7
# 306      NaN  qua  2021-05-26   21:45       Arouca      NaN      NaN
# 307      NaN  dom  2021-05-30   19:00      Rio Ave      NaN      NaN
#
#          away  Assistance                             Local  ...  \
# 0     Benfica           0     Estádio Municipal 22 de Junho  ...
# ...

# %%
df = df.iloc[:-2,:]

# %%
df.to_csv('fbref/dataset_201819.csv', index=False)
