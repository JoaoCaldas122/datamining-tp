# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('dataset_201819.csv')
df2 = pd.read_csv('dataset_201920.csv')
df3 = pd.read_csv('dataset_202021.csv')
df4 = pd.read_csv('dataset_202122.csv')
df5 = pd.read_csv('dataset_202223.csv')

# %%
df1 = df1.iloc[:, 2:]

# %%
df1
# Out:
#      Jornada  Dia        Data Horário             home  xG_home  xG_away  \
# 0          1  sex  2018-08-10   20:30          Benfica      1.9      1.0
# 1          1  sáb  2018-08-11   16:30  Vitória Setúbal      1.8      0.3
# 2          1  sáb  2018-08-11   19:00          Tondela      1.3      0.5
# 3          1  sáb  2018-08-11   21:00            Porto      4.5      0.1
# 4          1  dom  2018-08-12   16:00         Marítimo      2.2      0.8
# ..       ...  ...         ...     ...              ...      ...      ...
# 301       34  sáb  2019-05-18   15:30  Vitória Setúbal      2.0      2.2
# 302       34  sáb  2019-05-18   18:30            Porto      2.6      0.6
# 303       34  sáb  2019-05-18   18:30          Benfica      2.5      2.4
# 304       34  dom  2019-05-19   17:30          Tondela      1.9      2.4
# 305       34  dom  2019-05-19   20:00       Moreirense      1.3      2.4
#
#             away  Assistance                                        Local  \
# ...

# %%
df3 = df3.iloc[:, 2:]
df3 = df3.iloc[:-2,:]

# %%
df3
# Out:
#      Jornada  Dia        Data Horário          home  xG_home  xG_away  \
# 0        1.0  sex  2020-09-18   19:00     Famalicão      0.6      3.0
# 1        1.0  sex  2020-09-18   21:15       Vitória      0.4      0.5
# 2        1.0  sáb  2020-09-19   16:00      Nacional      1.3      0.3
# 3        1.0  sáb  2020-09-19   21:00         Porto      2.7      0.6
# 4        1.0  dom  2020-09-20   15:00   Santa Clara      2.2      1.5
# ..       ...  ...         ...     ...           ...      ...      ...
# 301     34.0  qua  2021-05-19   20:00  Portimonense      0.4      0.2
# 302     34.0  qua  2021-05-19   20:00    Moreirense      1.8      0.7
# 303     34.0  qua  2021-05-19   20:00       Vitória      0.8      1.9
# 304     34.0  qua  2021-05-19   20:00      Nacional      0.7      3.9
# 305     34.0  qua  2021-05-19   21:45   Sporting CP      1.8      0.7
#
#           away  Assistance                                        Local  ...  \
# ...

# %%
df4 = df4.iloc[:, 3:]
df4 = df4.iloc[:-2,:]

# %%
df4
# Out:
#      Jornada  Dia        Data Horário         home  xG_home  xG_away  \
# 0        1.0  sex  2021-08-06   20:15  Sporting CP      2.4      0.3
# 1        1.0  sáb  2021-08-07   12:45       Arouca      1.0      1.8
# 2        1.0  sáb  2021-08-07   18:00   Moreirense      1.7      1.4
# 3        1.0  sáb  2021-08-07   20:30     Marítimo      0.2      1.1
# 4        1.0  dom  2021-08-08   15:30      Tondela      1.7      1.5
# ..       ...  ...         ...     ...          ...      ...      ...
# 301     34.0  sáb  2022-05-14   18:00        Porto      1.6      0.7
# 302     34.0  sáb  2022-05-14   18:00     Marítimo      1.5      1.3
# 303     34.0  sáb  2022-05-14   20:30  Sporting CP      1.5      0.9
# 304     34.0  dom  2022-05-15   18:00    Famalicão      2.7      0.8
# 305     34.0  dom  2022-05-15   20:30      Vitória      2.6      0.8
#
#                away  Assistance                                        Local  \
# ...

# %%
df5 = df5.iloc[:, 1:]

# %%
df5
# Out:
#      Jornada  Dia        Data Horário          home  xG_home  xG_away  \
# 0          1  sex  2022-08-05   20:15       Benfica      2.7      0.4
# 1          1  sáb  2022-08-06   15:30       Rio Ave      0.2      1.4
# 2          1  sáb  2022-08-06   18:00       Estoril      1.8      1.5
# 3          1  sáb  2022-08-06   20:30         Porto      3.2      1.6
# 4          1  dom  2022-08-07   14:30   Santa Clara      0.3      1.3
# ..       ...  ...         ...     ...           ...      ...      ...
# 301       34  dom  2023-05-28   15:30       Benfica      NaN      NaN
# 302       34  dom  2023-05-28   15:30        Vizela      NaN      NaN
# 303       34  dom  2023-05-28   15:30  Portimonense      NaN      NaN
# 304       34  dom  2023-05-28   15:30         Porto      NaN      NaN
# 305       34  dom  2023-05-28   15:30       Rio Ave      NaN      NaN
#
#             away  Assistance                              Local  ...  \
# ...

# %%
frames = [df1,df2,df3,df4]
df6 = pd.concat(frames)

# %%
df6
# Out:
#      Jornada  Dia        Data Horário             home  xG_home  xG_away  \
# 0        1.0  sex  2018-08-10   20:30          Benfica      1.9      1.0
# 1        1.0  sáb  2018-08-11   16:30  Vitória Setúbal      1.8      0.3
# 2        1.0  sáb  2018-08-11   19:00          Tondela      1.3      0.5
# 3        1.0  sáb  2018-08-11   21:00            Porto      4.5      0.1
# 4        1.0  dom  2018-08-12   16:00         Marítimo      2.2      0.8
# ..       ...  ...         ...     ...              ...      ...      ...
# 301     34.0  sáb  2022-05-14   18:00            Porto      1.6      0.7
# 302     34.0  sáb  2022-05-14   18:00         Marítimo      1.5      1.3
# 303     34.0  sáb  2022-05-14   20:30      Sporting CP      1.5      0.9
# 304     34.0  dom  2022-05-15   18:00        Famalicão      2.7      0.8
# 305     34.0  dom  2022-05-15   20:30          Vitória      2.6      0.8
#
#                away  Assistance                              Local  ...  \
# ...

# %%
df7 = pd.read_csv('dataset_treino.csv')
df7 = df7.iloc[:, 1:]
df7
# Out:
#       Jornada  Dia        Data Horário             home  xG_home  xG_away  \
# 0         1.0  sex  2018-08-10   20:30          Benfica      1.9      1.0
# 1         1.0  sáb  2018-08-11   16:30  Vitória Setúbal      1.8      0.3
# 2         1.0  sáb  2018-08-11   19:00          Tondela      1.3      0.5
# 3         1.0  sáb  2018-08-11   21:00            Porto      4.5      0.1
# 4         1.0  dom  2018-08-12   16:00         Marítimo      2.2      0.8
# ...       ...  ...         ...     ...              ...      ...      ...
# 1219     34.0  sáb  2022-05-14   18:00            Porto      1.6      0.7
# 1220     34.0  sáb  2022-05-14   18:00         Marítimo      1.5      1.3
# 1221     34.0  sáb  2022-05-14   20:30      Sporting CP      1.5      0.9
# 1222     34.0  dom  2022-05-15   18:00        Famalicão      2.7      0.8
# 1223     34.0  dom  2022-05-15   20:30          Vitória      2.6      0.8
#
#                 away  Assistance                              Local  ...  \
# ...

# %%
df7.to_csv('dataset_treinofinal.csv')
